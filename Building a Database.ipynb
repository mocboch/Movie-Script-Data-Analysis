# %% [markdown]
# # Building a Database
# Using the insights from the last few notebooks, this notebook will create a Database in Postgres with SQL.

# %% [markdown]
# ## Targets
# The targets are the same ones downloaded in the last notebook, which were saved as 'BechdelData.csv'. That file can be loaded and stored in the Database more or less directly:

# %%
import json
import ast
import psycopg2
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings("ignore")
from urllib.request import urlopen
from urllib.error import HTTPError
from concurrent.futures import ThreadPoolExecutor

# %%
targets = pd.read_csv('BechdelData.csv')
targets = targets[['id', 'imdbid', 'title', 'year', 'rating']]
targets['imdbid'].fillna(-99, inplace=True)
targets['imdbid'] = targets['imdbid'].astype(int)
targets.to_csv('targets.csv', header=False, index=False, sep='~')

# %%
conn = psycopg2.connect(dbname='bechdel_test', user='postgres', password='guest')
cur = conn.cursor()

# %%
cur.execute(
    'CREATE TABLE bechdel_ratings('
    'bechdel_id      INT, '
    'imdb_id         INT, '
    'title           VARCHAR(255), '
    'year            SMALLINT, '
    'rating          SMALLINT);',
)

# %%
cur.copy_from(f:=open('targets.csv', 'r'), 'bechdel_ratings', columns=['bechdel_id', 'imdb_id', 'title', 'year', 'rating'], sep='~')

# %%
conn.commit()
cur.execute('SELECT * FROM bechdel_ratings')
cur.fetchall()
# Out:
# [(9602, 3155794, 'Passage de Venus', 1874, 0),
#  (9804, 14495706, 'La Rosace Magique', 1877, 0),
#  (9603, 2221420, 'Sallie Gardner at a Gallop', 1878, 0),
#  (9806, 12592084, 'Le singe musicien', 1878, 0),
#  (9816, 7816420, 'Athlete Swinging a Pick', 1881, 0),
#  (9831, 5459794, 'Buffalo Running', 1883, 0),
#  (9832, 8588366, 'L&#39;homme machine', 1885, 0),
#  (9614, 2075247, 'Man Walking Around the Corner', 1887, 0),
#  (9836, 8133192, 'Cockatoo Flying', 1887, 0),
#  (9837, 7411790, 'Child Carrying Flowers to Woman', 1887, 0),
#  (9838, 7541160, 'Jumping Over a Man&#39;s Back-Leapfrog', 1887, 0),
#  (9841, 7754902, 'Man Riding Jumping Horse', 1887, 0),
#  (9902, 8361552, 'Baboon Climbing a Pole', 1887, 0),
#  (8040, 392728, 'Roundhay Garden Scene', 1888, 0),
#  (9615, 1758563, 'Accordion Player', 1888, 0),
#  (9616, 343112, 'Traffic Crossing Leeds Bridge', 1888, 0),
#  (9675, 3274100, 'Pferd und Reiter Springen uber ein Hindernis', 1888, 0),
#  (9947, 2116853, 'Brighton Street Scene', 1888, 0),
#  (9619,
#   466876,
#   'Leisurely Pedestrians, Open Topped Buses and Hansom Cabs with Trotting Horses',
#   1889,
#   0),
#  (9945, 2116898, 'Hyde Park Corner', 1889, 0),
#  (9617, 361921, 'Monkeyshines, No. 1', 1890, 0),
#  (9618, 416046, 'Monkeyshines, No. 2', 1890, 0),
#  (9621, 1202028, 'London&#39;s Trafalgar Square', 1890, 0),
#  (9678, 416047, 'Monkeyshines, No. 3', 1890, 0),
#  (9946, 5285442, 'Mosquinha', 1890, 0),
#  (6199, 12, 'Arrival of a Train, The', 1896, 0),
#  (9672, 1428455, 'Sandow', 1896, 0),
#  (9949, 1672718, 'Alger: rue Bab-Azoun', 1896, 0),
#  (9950, 1736599, 'Lassage des boeufs pour le labour', 1896, 0),
#  (9901, 222137, 'Lancement d&#39;un navire', 1896, 0),
#  (9328, 41, 'Bataille de neige', 1897, 0),
#  (4978, 135696, 'Four Heads Are Better Than One', 1898, 0),
#  (5410, 211, 'Astronomer&#39;s Dream; or, The Man in the Moon, The', 1898, 0),
#  (5411, 224240, 'Temptation of St. Anthony, The', 1898, 0),
#  (4994, 246, 'A Turn of the Century Illusionist', 1899, 0),
#  (5914, 230, 'Cinderella', 1899, 3),
#  (1594, 291476, 'Sherlock Holmes Baffled', 1900, 0),
#  (4271, 300, 'Enchanted Drawing, The', 1900, 0),
#  (4343, 304, 'Grandma&#39;s Reading Glass', 1900, 0),
#  (4344,
#   272,
#   'As Seen Through A Telescope (a.k.a The Professor and His Field Glass)',
#   1900,
#   0),
#  (4345,
#   257654,
#   'Explosion of a Motor Car (a.k.a The Dlights of Automobiling)',
#   1900,
#   0),
#  (4346, 306, 'Hamlet ( Le Duel d&#39;Hamlet)', 1900, 0),
#  (4993, 135453, 'One-Man Band, The', 1900, 0),
#  (5069, 377995, 'Grandma Threading Her Needle', 1900, 0),
#  (5072,
#   230746,
#   'Searching Ruins on Broadway, Galveston, for Dead Bodies',
#   1900,
#   0),
#  (5438, 313, 'Let Me Dream Again', 1900, 0),
#  (5446, 227438, 'Doctor and the Monkey, The', 1900, 0),
#  (4995, 359, 'L&#39;homme a la tete en caoutchouc', 1901, 0),
#  (5437, 258104, 'Reve et realite', 1901, 0),
#  (5500, 131934, 'Bluebeard', 1901, 0),
#  (1252, 417, 'Le voyage dans la lune', 1902, 0),
#  (5431, 229024, 'Gulliver&#39;s Travels', 1902, 0),
#  (5432,
#   367177,
#   'Twentieth Century Tramp; or, Happy Hooligan and His Airship, The',
#   1902,
#   0),
#  (5443, 413, 'Mephistopheles&#39; School of Magic', 1902, 0),
#  (1319, 439, 'Great Train Robbery, The', 1903, 0),
#  (5002, 135180, 'Infernal Boiling Pot, The', 1903, 0),
#  (5063, 455, 'Music Lover, The', 1903, 0),
#  (5064, 223755, 'Monster, The', 1903, 0),
#  (5683, 189498, 'Enchanted Well, The', 1903, 0),
#  (5224, 215664, 'Cook in Trouble, The', 1904, 0),
#  (5404, 135179, 'Living Playing Cards, The', 1904, 0),
#  (5601, 135631, 'Untamable Whiskers, The', 1904, 0),
#  (6135, 499, 'Le voyage a travers l&#39;impossible', 1904, 0),
#  (5003, 135690, 'Scheming Gambler&#39;s Paradise, The', 1905, 0),
#  (5602, 215575, 'Black Imp, The', 1905, 0),
#  (1349, 574, 'Story of the Kelly Gang, The', 1906, 1),
#  (5024, 216016, 'Mysterious Retort, The', 1906, 0),
#  (5435, 554, 'Humorous Phases of Funny Faces', 1906, 0),
#  (5603, 135122, 'Hilarious Posters, The', 1906, 0),
#  (5684, 567, '400 Tricks of the Devil, The', 1906, 0),
#  (1386, 33804, 'Lady Eve, The', 1941, 2),
#  (1682, 33533, 'Devil and Miss Jones, The', 1941, 3),
#  (1941, 33727, 'Mr. Bug Goes to Town', 1941, 1),
#  (2410, 33717, 'High Sierra', 1941, 1),
#  (2436, 34398, 'Wolf Man, The', 1941, 2),
#  (2446, 33459, 'Cheers for Miss Bishop', 1941, 3),
#  (2468, 33902, 'Men of Boys Town', 1941, 1),
#  (2867, 33627, '49th Parallel', 1941, 0),
#  (2906, 33436, 'Buck Privates', 1941, 3),
#  (2910, 33723, 'Hold That Ghost', 1941, 3),
#  (3717, 33891, 'Meet John Doe', 1941, 3),
#  (4359, 34240, 'Sullivan&#39;s Travels', 1941, 3),
#  (6171, 33928, 'Murder by Invitation', 1941, 3),
#  (6318, 33802, 'Ladies In Retirement', 1941, 1),
#  (7329, 34248, 'Suspicion', 1941, 3),
#  (8625, 34241, 'Sun valley serenade', 1941, 0),
#  (8983, 33729, 'How Green Was My Valley', 1941, 3),
#  (9025, 34091, 'Reluctant Dragon, The', 1941, 3),
#  (9192, 33787, 'King of the Zombies', 1941, 3),
#  (10347, 33373, 'Ball of Fire', 1941, 2),
#  (681, 35019, 'Major and the Minor, The', 1942, 3),
#  (689, 35140, 'Now, Voyager', 1942, 3),
#  (1076, 34583, 'Casablanca', 1942, 1),
#  (1289, 35015, 'Magnificent Ambersons, The', 1942, 2),
#  (1116, 34492, 'Bambi', 1942, 1),
#  (1388, 35360, 'Son of Fury: The Story of Benjamin Blake', 1942, 1),
#  (1675, 34746, 'For Me and My Gal', 1942, 3),
#  (1686, 34882, 'I Married an Angel', 1942, 3),
#  (2708, 34587, 'Cat People', 1942, 3),
#  (3518, 34521, 'Black Dragons', 1942, 0),
#  (3789, 34591, 'There Was a Father', 1942, 0),
#  (3875, 35415, 'Tales of Manhattan', 1942, 2),
#  (4475, 33874, 'Man Who Came to Dinner, The', 1942, 3),
#  (4870, 35567, 'Woman of the Year', 1942, 3),
#  (5303, 35446, 'To Be or Not to Be', 1942, 0),
#  (5859, 35317, 'Sherlock Holmes and the Secret Weapon', 1942, 1),
#  (5938, 35279, 'Saboteur', 1942, 1),
#  (5939, 35279, 'Saboteur', 1942, 1),
#  (6384, 35093, 'Mrs. Miniver', 1942, 3),
#  (7696, 36326, 'Saludos Amigos', 1942, 0),
#  (7697, 34613, 'Corpse Vanishes, The', 1942, 1),
#  (10343, 34770, 'Gay Sisters, The', 1942, 3),
#  (1374, 36230, 'Old Acquaintance', 1943, 3),
#  (1375, 36515, 'Watch on the Rhine', 1943, 3),
#  (1691, 35942, 'Girl Crazy', 1943, 1),
#  (1955, 36027, 'I Walked with a Zombie', 1943, 3),
#  (1959, 36363, 'Sky&#39;s the Limit, The', 1943, 1),
#  (1987, 36323, 'Sahara', 1943, 0),
#  (1988, 35957, 'Guadalcanal Diary', 1943, 0),
#  (2407, 36418, 'Tender Comrade', 1943, 3),
#  (3753, 36506, 'Day of Wrath', 1943, 3),
#  (3839, 36112, 'Life and Death of Colonel Blimp, The', 1943, 2),
#  (2763, 52169, 'Screaming Skull, The', 1958, 2),
#  (2823, 50706, 'Mon Oncle', 1958, 3),
#  (3146, 52311, 'Touch of Evil', 1958, 1),
#  (3056, 51658, 'Gigi', 1958, 2),
#  (3238, 51525, 'Defiant Ones, The', 1958, 0),
#  (3321, 51383, 'Auntie Mame', 1958, 3),
#  (3926, 52182, 'Separate Tables', 1958, 3),
#  (3977, 52225, 'South Pacific', 1958, 3),
#  (4211, 51773, 'Indiscreet', 1958, 3),
#  (4410, 51755, 'I Bury the Living', 1958, 1),
#  (4849, 51776, 'Inn of the Sixth Happiness, The', 1958, 3),
#  (6012, 51459, 'Cat on a Hot Tin Roof', 1958, 3),
#  (6938, 51579, 'Love Is My Profession', 1958, 3),
#  (7054, 51422, 'Blood of the Vampire', 1958, 0),
#  (7135, 51808, 'Hidden Fortress, The', 1958, 0),
#  (7606, 51786, 'It! The Terror from Beyond Space', 1958, 1),
#  (8344, 52017, 'Brink of Life', 1958, 3),
#  (8450, 51758, 'I Want To Live!', 1958, 3),
#  (10341, 51911, 'Marjorie Morningstar', 1958, 3),
#  (10521, 52218, 'Some Came Running', 1958, 2),
#  (10562, 51608, 'Female, The', 1958, 2),
#  (10570, 51818, 'King Creole', 1958, 1),
#  (10789, 50193, 'Night Heaven Fell, The', 1958, 3),
#  (236, 53198, '400 Blows, The', 1959, 0),
#  (474, 53285, 'Sleeping Beauty', 1959, 3),
#  (1419, 52618, 'Ben-Hur', 1959, 3),
#  (1256, 52948, 'Journey to the Center of the Earth', 1959, 1),
#  (1555, 53131, 'Nun&#39;s Story, The', 1959, 3),
#  (1591, 52722, 'Darby O&#39;Gill and the Little People', 1959, 3),
#  (2023, 53291, 'Some Like It Hot', 1959, 3),
#  (2095, 52918, 'Imitation of Life', 1959, 3),
#  (2228, 53125, 'North By Northwest', 1959, 1),
#  (2645, 53318, 'Suddenly, Last Summer', 1959, 3),
#  (2796, 52846, 'Giant Gila Monster, The', 1959, 3),
#  (3119, 51372, 'Araya', 1959, 3),
#  (3166, 53363, 'Tingler, The', 1959, 1),
#  (3442, 53428, 'Come Dance with Me!', 1959, 3),
#  (3525, 53134, 'Good Morning (Ohay&ocirc;)', 1959, 3),
#  (3608, 52861, 'Great War, The', 1959, 1),
#  (4050, 52844, 'Ghost of Dragstrip Hollow', 1959, 3),
#  (4065, 52655, 'A Bucket of Blood', 1959, 2),
#  (4199, 52561, 'Anatomy of a Murder', 1959, 1),
#  (4373, 51744, 'House on Haunted Hill', 1959, 3),
#  ...]

# %% [markdown]
# ## TMDb Metadata
# This .csv created using the code in the previous notebook:

# %%
df = pd.read_csv('tmdb_data_targets.csv', index_col=0, converters={"genre_ids": ast.literal_eval})
df['imdbid'] = df['imdbid'].fillna(-99).astype(int)
df1 = df[['id', 'imdbid', 'title', 'original_language', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
cur.execute(
    'CREATE TABLE tmdb_data('
    'tmdb_id            INT, '
    'imdb_id            INT, '
    'title              VARCHAR(255),'
    'original_language  VARCHAR(2),'
    'release_date       VARCHAR(10),'
    'popularity         NUMERIC(8,3),'
    'vote_average       NUMERIC(5,3),'
    'vote_count         INT);'
)

# %%
df1.to_csv('df1.csv', header=False, index=False, sep='~')
cur.copy_from(f:=open('df1.csv', 'r', encoding='cp850'), 'tmdb_data', columns=['tmdb_id', 'imdb_id', 'title', 'original_language', 'release_date', 'popularity', 'vote_average', 'vote_count'], sep='~')

# %% [markdown]
# Note: Added overview and re-did this in the console.

# %%
df
# Out:
#                        backdrop_path       id  \
# 0   /6vYffq6NoneNmNPp6IsobnnlrHS.jpg   315946
# 0                                NaN   766094
# 0                                NaN   751212
# 0                                NaN   585297
# 0   /gCm6ggiw0YzIZkchHbDWrQbcOiP.jpg   159897
# ..                               ...      ...
# 0   /wODqakS0jinTUECNS6n4VomQbew.jpg   967847
# 0   /oe7mWkvYhK4PLRNAVSvonzyUXNy.jpg   359410
# 0   /xRd1eJIDe7JHO5u4gtEYwGn5wtf.jpg   823464
# 0   /zVMdsmRUH2U1bZSYr8GLZkfs3mi.jpg   957304
# 0    /TGsfNWkASegCfAn6ED1b08a9O6.jpg  1125311
#
#                      original_title  \
# 0                  Passage de Venus
# 0                 La Rosace Magique
# 0                 Le Singe Musicien
# 0                   L'Homme Machine
# 0       Man Walking Around a Corner
# ..                              ...
# 0       Ghostbusters: Frozen Empire
# 0                        Road House
# 0   Godzilla x Kong: The New Empire
# 0                  Drive-Away Dolls
# 0                         Imaginary
#
#                                              overview  \
# 0   Photo sequence of the rare transit of Venus ov...
# 0   Praxinoscope strip of a shifting rosette. Seri...
# 0   A pre-cinematograph colour animation of the mo...
# 0   Animated stick drawings representing a man wal...
# 0   The last remaining production of Le Prince's L...
# ..                                                ...
# 0   When the discovery of an ancient artifact unle...
# 0   Ex-UFC fighter Dalton takes a job as a bouncer...
# 0   Following their explosive showdown, Godzilla a...
# 0   Jamie, an uninhibited free spirit bemoaning ye...
# 0   When Jessica moves back into her childhood hom...
#
#                          poster_path media_type  adult  \
# 0    /XWPDZzK7N2WQcejI8W96IxZEeP.jpg      movie  False
# 0   /5zeVMAp3R4QHGarSc4Bf3B1uBY2.jpg      movie  False
# 0   /fx2gnyV2n9KdOCyGzQtVnpB9bIg.jpg      movie  False
# 0   /vkxWQys2cqBU7JpWL4PWYG8Va9Z.jpg      movie  False
# 0   /3vIpxTUyCFSFagJsGaxFXcR8mOt.jpg      movie  False
# ..                               ...        ...    ...
# 0   /e1J2oNzSBdou01sUvriVuoYp0pJ.jpg      movie  False
# 0   /bXi6IQiQDHD00JFio5ZSZOeRSBh.jpg      movie  False
# 0   /z1p34vh7dEOnLDmyCrlUVLuoDzd.jpg      movie  False
# 0   /gavGnAMTXPkpoFgG0stwgIgKb64.jpg      movie  False
# 0   /9u6HEtZJdZDjPGGJq6YEuhPnoan.jpg      movie  False
#
#                               title original_language       genre_ids  \
# 0                  Passage of Venus                fr           (99,)
# 0                 The Magic Rosette                xx           (16,)
# 0               The Musician Monkey                xx           (16,)
# 0                   L'Homme Machine                xx           (16,)
# 0       Man Walking Around a Corner                xx           (99,)
# ..                              ...               ...             ...
# 0       Ghostbusters: Frozen Empire                en    (14, 12, 35)
# 0                        Road House                en        (28, 53)
# 0   Godzilla x Kong: The New Empire                en   (878, 28, 12)
# 0                  Drive-Away Dolls                en        (35, 80)
# 0                         Imaginary                en  (27, 9648, 53)
#
#     popularity release_date  video  vote_average  vote_count    imdbid
# 0        4.786   1874-12-09  False         6.210         105   3155794
# 0        2.194   1878-05-07  False         5.800          19  14495706
# 0        2.560   1878-05-07  False         5.900          25  12592084
# 0        1.149   1885-01-01  False         4.629          31   8588366
# 0        5.529   1887-08-18  False         4.900          80   2075247
# ..         ...          ...    ...           ...         ...       ...
# 0      603.739   2024-03-20  False         6.671         873  21235248
# 0      483.627   2024-03-08  False         7.024        1810   3359350
# 0     3853.790   2024-03-27  False         7.278        2211  14539740
# 0       81.501   2024-02-22  False         5.531         208  19356262
# 0      154.811   2024-03-06  False         6.210         312  26658104
#
# [10118 rows x 16 columns]

# %%
conn.commit()
cur.execute('SELECT * FROM tmdb_data;')
cur.fetchone()
# Out:
# (315946,
#  3155794,
#  'Passage of Venus',
#  'fr',
#  '1874-12-09',
#  Decimal('4.786'),
#  Decimal('6.210'),
#  105)

# %% [markdown]
# ### Genres

# %%
url = "https://api.themoviedb.org/3/genre/movie/list"
auth = 'Bearer ' + open('tmdbauth.txt').read() 
headers = {
    'accept' : 'application/json',
    'Authorization' : auth
}
response = requests.get(url, headers=headers)
genre_dict = {}
for genre in json.loads(response.text)['genres']:
    genre_dict[genre['id']] = genre['name']
genre_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
df = df.set_index('imdbid')
ids, genres = [], []
for i in df.index:
    for j in df['genre_ids'][i]:
        try: ids.append(i)
        except: ids.append(np.nan)
        try: genres.append(genre_dict[j])
        except: genres.append(np.nan)
df2 = pd.DataFrame({'ids':ids, 'genres':genres}).dropna()

# %%
df2.to_csv('df2.csv', header=False, index=False, sep='~')
cur.execute(
    'CREATE TABLE genre('
    'imdb_id    INT,'
    'genre      VARCHAR(25)'
    ');'
)
cur.copy_from(f:=open('df2.csv', 'r'), 'genre', columns=['imdb_id', 'genre'], sep='~')

# %% [markdown]
# ## Scraping Scripts
# At this point, there is still a lot of uncertainty in terms of the data quality resulting from scraping scripts from IMSDb as I did in the previous notebook. In this section I will dig a little deeper to ensure only quality data gets uploaded to the database.

# %%
data = pd.read_csv('exploratory_data.csv')

# %% [markdown]
# Some of the issues to deal with before pushing to the Database are:
# - Some of the scripts are blank between the pre and /pre tags
#     - It looks like 25 scripts have this issue of the ~500 in the exploratory set
#     - Checking on a few of them, it seems there is simply no script available for those movies, meaning that if the scraped HTML from IMSDb is blank in between the pre tags, it can be discarded.
# - Some scripts have multiple sets of pre tags
#     - The innermost set usually contains the script
# - It's possible that some scripts are available at different URLs- try scraping the script URL from the metadata page
# - Release year should be matched up before scraping the script

# %% [markdown]
# ### Blank Scripts (between the pre tags)

# %%
data['script'] = pd.Series()
for i in data.index:
    data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# Out:
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\2810471973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script'][i] = data['html'][i].split('<pre>')[-1].split('</pre>')[0]

# %%
data['release_year'] = pd.Series()
data['release_month'] = pd.Series()
data['script_year'] = pd.Series()
data['script_month'] = pd.Series()

pattern = r'(.*)(\d\d\d\d)'
for i in data.index:
    try:
        match = re.search(pattern, data.loc[i].release_date)
        data['release_year'][i] = match[2]
        data['release_month'][i] = match[1]
    except TypeError: pass
    try:
        match = re.search(pattern, data.loc[i].script_date)
        data['script_year'][i] = match[2]
        data['script_month'][i] = match[1]
    except TypeError: pass

    


test = data[data['year'] == data['release_year'].fillna(0).astype(int)]#.fillna(0).astype(int)]
#data[data['script'] == '']
# Out:
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['release_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_year'][i] = match[2]
# C:\Users\Mark\AppData\Local\Temp\ipykernel_21516\956866200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['script_month'][i] = match[1]

# %%
data[data['script'] != '']
# Out:
#      Unnamed: 0     id      imdbid                title  rating  year  \
# 0           202   1227     18033.0                   It       3  1927
# 2           276   1328     22958.0          Grand Hotel       3  1932
# 3           292   6063     23427.0             Scarface       1  1932
# 4           416    174     32138.0    Wizard of Oz, The       3  1939
# 5           481   1266     33467.0         Citizen Kane       1  1941
# ..          ...    ...         ...                  ...     ...   ...
# 536        9665   9265   4566758.0                Mulan       3  2020
# 537        9858  10052   1160419.0                 Dune       3  2021
# 538        9971  10221  11245972.0               Scream       3  2022
# 539       10101  10684  10278918.0               Willow       3  2022
# 540       10182  10926   5971474.0  Little Mermaid, The       3  2023
#
#                                                   html    release_date  \
# 0    <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...  September 2017
# 2    <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      April 1932
# 3    <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# 4    <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# 5    <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# ..                                                 ...             ...
# 536  <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# 537  <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...             NaN
# 538  <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# 539  <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
# 540  <html>\r\n<head>\r\n<!-- Google tag (gtag.js) ...      not listed
#
#        script_date                                             script  \
# 0       March 2014  \r\n\r\n\r\n<b>                               ...
# 2       not listed  \r\n\r\n\r\n<b>                               ...
# 3       not listed  #00766\r\n\r\n\r\n\r\n\r\n         "Enjoy your...
# 4       March 1939  FADE IN -- Title:\r\n\r\nFor nearly forty year...
# 5       not listed  <html>\r\n<head>\r\n<script>\r\n<b><!--\r\n</b...
# ..             ...                                                ...
# 536  December 1998                                                NaN
# 537            NaN                                                NaN
# 538      July 1995                                                NaN
# 539     not listed                                                NaN
# 540  December 1989                                                NaN
#
#     release_year release_month script_year script_month
# 0           2017    September         2014       March
# 2           1932        April          NaN          NaN
# 3            NaN           NaN         NaN          NaN
# 4            NaN           NaN        1939       March
# 5            NaN           NaN         NaN          NaN
# ..           ...           ...         ...          ...
# 536          NaN           NaN        1998    December
# 537          NaN           NaN         NaN          NaN
# 538          NaN           NaN        1995        July
# 539          NaN           NaN         NaN          NaN
# 540          NaN           NaN        1989    December
#
# [516 rows x 14 columns]

# %%
notFound = urlopen('https://imsdb.com/scripts/asd.html').read()
def scrape_imsdb(title, year, imdb_id, notFound=notFound):
    movie_year, script_date, script_url, script = -99, -99, -99, -99
    t = title.replace(' ', '%20')
    url = 'https://imsdb.com/Movie%20Scripts/' + t + '%20Script.html'
    try: 
        page = urlopen(url)
        html_bytes = page.read()
        html = html_bytes.decode('utf-8')
        
        movie_date_pattern = r'(<b>Movie Release Date</b> : )(.*)(\d\d\d\d)(<br>)'
        try: movie_year = re.search(movie_date_pattern, html)[3]
        except TypeError: movie_year = '9999'
        
        if (int(movie_year) == int(year)) or (int(movie_year) == 9999):
            script_date_pattern = r'(<b>Script Date</b> : )(.*)(<br>)'
            try: script_date = re.search(script_date_pattern, html)[2]
            except TypeError: pass
        
            script_url_pattern = r'(<a href=")(.*)(">Read &quot;)(.*)(&quot; Script</a>)'
            try: script_url = re.search(script_url_pattern, html)[2]
            except TypeError: pass
            
            script_url = 'https://imsdb.com' + script_url
            page = urlopen(script_url)
            html_bytes = page.read()
            if html_bytes == notFound:
                pass
            else:
                html = html_bytes.decode('utf-8')
                script = BeautifulSoup(html.split('<pre>')[-1].split('</pre>')[0]).get_text()
        
        
    except (HTTPError, UnicodeDecodeError, IndexError):
        pass
    finally:
        tup = (title, imdb_id, movie_year, script_date, script)
        return tup

# %%
'''
processes = []
with ThreadPoolExecutor(max_workers=32) as executor:
    for i in targets.index:
        processes.append(executor.submit(scrape_imsdb, targets['title'][i], targets['year'][i], targets['imdbid'][i]))


dict = {}
for task in processes:
    dict[task.result()[0]] =  (task.result()[1], task.result()[2], task.result()[3], task.result()[4])
'''

# %%
'''
df = pd.DataFrame.from_dict(dict).T
df.rename(columns={0:'imdb_id', 1:'release_year', 2:'script_date', 3:'script'}, inplace=True)
df = df[df['script'] != -99]
df.replace('9999', np.nan, inplace=True)
df.replace(-99, np.nan, inplace=True)
df.reset_index(inplace=True)
df.set_index('imdb_id', inplace=True)
df.rename(columns={'index':'title'}, inplace=True)
df.to_csv('imsdb_scripts.csv')
'''

# %%
df = pd.read_csv('imsdb_scripts.csv', index_col=0)
df = df.drop(columns=['title', 'release_year']).reset_index()
df.to_csv('scripts_upload.csv', header=False, index=False, na_rep='none')

# %% [markdown]
# Psycopg2 doesn't play nice with formatted text; the SQL to upload this table is in Table Creation.sql.

# %%
cur.close()
conn.close()

# %%
conn.rollback()

# %%
conn.commit()
